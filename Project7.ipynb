# %% [markdown]
# <font color='blue' size=5><b>Комментарий ревьюера</b></font>
#
# <font color='blue'>Привет, Айдар! Меня зовут Павел Григорьев, и я буду проверять этот проект.<br>Моя основная цель - не указать на совершённые тобой ошибки, а поделиться своим опытом и помочь тебе совершенствоваться как профессионалу.<br>Спасибо за проделанную работу! Предлагаю общаться на «ты».</font>
# <details>
# 	<summary><u>Инструкция по организационным моментам (кликабельно)</u>⤵</summary>
# <font color='blue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font>
#
#
# ---
#
#
# <font color='blue'>синий текст - просто текст комментария</font>
#
# <font color='green'>✔️ и зеленый текст - все отлично</font>
#
# <font color='orange'>⚠️ и оранжевый текст - сделано все правильно, однако есть рекомендации, на что стоит обратить внимание</font>
#
# <font color='red'>❌ и красный текст - есть недочеты</font>
#
#
# </details>
# </br>
# <font color='blue'>Пожалуйста, не удаляй мои комментарии в случае возврата работы, так будет проще разобраться, какие были недочеты, а также сразу увидеть исправленное. </font>
#
# <font color='blue'>Ответы на мои комментарии лучше тоже помечать.
#
# Например:</font><font color='purple'><b>Комментарий студента</b></font>
#
# <font color='blue'><b>Давай смотреть, что получилось!</b></font>

# %% [markdown]
# <font color='blue' size=3><b>Комментарий ревьюера 2</b></font>
#
# <font color='blue'>Привет еще раз. Спасибо, за исправления. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.</font>

# %% [markdown]
# <font color='blue' size=3><b>Комментарий ревьюера 3</b></font>
#
# <font color='blue'>Привет еще раз. Спасибо, за исправления. Оформление комментариев по работе сохраняется. Только обозначим, что это третья итерация.</font>

# %% [markdown]
# Проект выполнен в Jupyter Notebook 6.4.5.

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара 2:</b> Добавил установку новой версии библиотеки в тетрадь проекта!</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 3: </b></font> ✔️\
# <font color='green'> 👍</font>

# %%
pip install scikit-learn==1.5.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
#The scikit-learn version is 1.5.0.
# Out:
# The scikit-learn version is 1.5.0.

# %%
import numpy
print('The numpy version is {}.'.format(numpy.__version__))
#The numpy version is 1.20.3.
# Out:
# The numpy version is 1.20.3.

# %%
import scipy
print('The scipy version is {}.'.format(scipy.__version__))
#The scipy version is 1.10.1.
# Out:
# The scipy version is 1.10.1.

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Привет тебе, Павел! Спасибо за твое время и опыт, которые ты обнажаешь передо мной проводя ревью моего этого учебного проекта! И добавил ниже V</div>

# %% [markdown]
# <font color='blue' size=3><b>Комментарий ревьюера 2</b></font>
#
# <font color='blue'>Привет еще раз. Спасибо, за исправления. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.</font>

# %% [markdown]
# Обновил версию scikit-learn до 1.5.0.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ⚠️\
# <font color='darkorange'>В проекте нет обновления sklearn, будет импортироваться дефолтная для среды Практикума - `0.24.1`</font>

# %%
#pip install scipy

# %%
#pip install numpy

# %%
pip install shap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install phik
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Проект по разработке решения для интернет-магазина "В один клик", которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# Для решение этой задачи я сначала разработаю модель, которая предскажет вероятность снижения покупательской активности. Затем выделю сегмент покупателей, проанализирую его и предложу, как увеличить его покупательскую способность. Буду использовать данные моделирования, данные о прибыли покупателей и исходные данные.
#
# Сначала я загружу данные из 4-х csv-файлов:
#
# market_file.csv - таблица, содержащая данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
# market_money.csv - таблица с данными о выручке, которую получает магазин с покупателя, т.е. сколько покупатель всего потратил за период взаимодействия с сайтом.
#
# market_rime.csv - таблица с данными о времени (в минутах), которое покупатель провел на сайте в течение периода.
#
# money.csv - таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
# После загрузки датафреймов я проведу предобработку (пропуски и дубликаты), после чего проведу исследовательский и корреляционный анализы, построю графики.
#
# Затем посмотрю модели машинного обучения.

# %% [markdown]
# # Описание данных

# %% [markdown]
# market_file.csv
#
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
#     id — номер покупателя в корпоративной базе данных.
#
#     Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
#
#     Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
#
#     Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
#
#     Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
#
#     Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
#
#     Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
#
#     Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
#
#     Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
#
#     Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
#
#     Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
#
#     Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
#
#     Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %% [markdown]
# market_money.csv
#
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#
#     id — номер покупателя в корпоративной базе данных.
#
#     Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
#
#     Выручка — сумма выручки за период.

# %% [markdown]
# market_time.csv
#
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#
#     id — номер покупателя в корпоративной базе данных.
#
#     Период — название периода, во время которого зафиксировано общее время.
#
#     минут — значение времени, проведённого на сайте, в минутах.

# %% [markdown]
# money.csv
#
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
#     id — номер покупателя в корпоративной базе данных.
#
#     Прибыль — значение прибыли.

# %%
import phik

from phik import phik_matrix

from phik.report import plot_correlation_matrix

# %%
from scipy import stats as st

import matplotlib.pyplot as plt

import numpy as np

import pandas as pd

from math import factorial

import seaborn as sns

from sklearn.model_selection import (
    RandomizedSearchCV,
    train_test_split
)

from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder, 
    StandardScaler, 
    MinMaxScaler,
    RobustScaler,
    LabelEncoder
)

from sklearn.linear_model import (
    LinearRegression,
    LogisticRegression
)

from sklearn.neighbors import KNeighborsClassifier

from sklearn.tree import DecisionTreeClassifier

from sklearn.svm import SVC

from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    recall_score,
    precision_score,
    confusion_matrix,
    accuracy_score,
    roc_auc_score
)

from sklearn.pipeline import Pipeline

from sklearn.compose import ColumnTransformer

from sklearn.impute import SimpleImputer

import shap

from sklearn.inspection import permutation_importance

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️ <br>
# <font color='green'>Здорово, что все импорты находятся в одной ячейке.<br>
# Если хочешь сделать ещё лучше, соблюдай стандарт PEP-8, разбей импорты на функциональные группы, раздели группы пустой строкой. Можно в каждой группе отсортировать импорты в алфавитном порядке.<br>
# Ссылка для ознакомления: https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html
# </font>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> По моему мнению, раз все выполняется у меня на машине без ошибок, то значит, что я инсталировал все модели. </div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> \
# <font color='blue'>
# Код должен полностью исполняться, у тех кому ты демонстрируешь свою работу. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# Для проверки, так же, можно поднять ядро на локальной машине из `da_practicum_env.yml` из "Поезные инструкции для работы".
#
# Важно убедиться, что все ячейки проекта исполнились - можно просто пролистать работу до конца и убедиться, что последняя ячейка исполнена. Такая проверка поможет тебе убедиться, что твоё решение будет должным образом воспроизведено во время ревью или во время передачи его заказчику - это очень важный этап, пренебрегать которым не стоит:)
#
# Обрати также внимание, что если твой проект без ошибок работает локально, это не значит, что на платформе будет так же - есть разные окружения, платформа имитирует окружение заказчика, и мы должны обеспечить работоспособность нашего решения на окружении заказчика в первую очередь.</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'> ~~Ошибка исполнения кода. Не все модели инсталированы.~~</font>

# %% [markdown]
# Ипортировали все необходимые библиотеки.

# %% [markdown]
# # Шаг 1. Загрузка данных

# %% [markdown]
# 1.1 Загрузите данные. Файлы market_file.csv, market_money.csv, market_time.csv, money.csv доступны по ссылкам в описании данных или через пути к ним:
#
#     /datasets/market_file.csv
#     /datasets/market_money.csv
#     /datasets/market_time.csv
#     /datasets/money.csv
#
# Обратите внимание: в некоторых файлах разделитель значений — точка с запятой, а разделитель десятичных значений — запятая.

# %%
try:
    mf = pd.read_csv('/datasets/market_file.csv',sep=',')
except:
    mf = pd.read_csv('market_file.csv',sep=',')

# %%
try:
    mm = pd.read_csv('/datasets/market_money.csv',sep=',')
except:
    mm = pd.read_csv('market_money.csv',sep=',')

# %%
try:
    mt = pd.read_csv('/datasets/market_time.csv',sep=',')
except:
    mt = pd.read_csv('market_time.csv',sep=',')

# %%
try:
    mo = pd.read_csv('/datasets/money.csv',sep=';', decimal = ',')
except:
    mo = pd.read_csv('money.csv',sep=';', decimal = ',')

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'>При загрузке в Пандас разделитель дроби можно указывать аргументом `decimal = ','`, тогда данные загружаются в корректном типе данных. (money)</font>
# ```text
# Обратите внимание: в некоторых файлах разделитель значений — точка с запятой, а разделитель десятичных значений — запятая.
# ```

# %%
mf.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
mm.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
mm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
mt.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
mt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
#mo['Прибыль'] = pd.to_numeric(mo['Прибыль'].str.replace(',', '.'), errors='coerce')

# %%
mo.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %%
mo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# 1.2 Проверьте, что данные в таблицах соответствуют описанию. Исследованием и объединением данных вы займётесь позже.

# %% [markdown]
# ### Выводы по шагу 1. Подгрузил 4 датафрейма, верхнеуровнево изучил содержимое. В 4-м датафрейме был другой разделитель между данными и запятая вместо точки для разделения целой и дробных частей. Учел это при подгрузке данных. Проверил, что данные в таблицах соответствуют описанию.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Данные загружены корректно, первичный осмотр проведен.</font>

# %% [markdown]
# # Шаг 2. Предобработка данных

# %% [markdown]
# Проведите необходимую предобработку данных. Названия столбцов можно оставить кириллическими.

# %% [markdown]
# Сначала рассмотрим, какие уникальные значения есть в датафреймах.

# %%
mf['Покупательская активность'].unique()
# Out:
# array(['Снизилась', 'Прежний уровень'], dtype=object)

# %%
mf['Тип сервиса'].unique()
# Out:
# array(['премиум', 'стандартт', 'стандарт'], dtype=object)

# %%
mf['Тип сервиса'] = (
    mf['Тип сервиса']
    .str.replace('стандартт','стандарт',regex=True)
)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> 👍</font>

# %%
mf['Разрешить сообщать'].unique()
# Out:
# array(['да', 'нет'], dtype=object)

# %%
mf['Популярная_категория'].unique()
# Out:
# array(['Товары для детей', 'Домашний текстиль', 'Косметика и аксесуары',
#        'Техника для красоты и здоровья', 'Кухонная посуда',
#        'Мелкая бытовая техника и электроника'], dtype=object)

# %%
mf['Популярная_категория'] = (
    mf['Популярная_категория']
    .str.replace('аксесуары','аксессуары',regex=True)
)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> 👍</font>

# %%
mm['Период'].unique()
# Out:
# array(['препредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц'],
#       dtype=object)

# %%
mt['Период'].unique()
# Out:
# array(['текущий_месяц', 'предыдцщий_месяц'], dtype=object)

# %%
mt['Период'] = (
    mt['Период']
    .str.replace('предыдцщий_месяц','предыдущий_месяц',regex=True)
)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> 👍</font>

# %%
mf.describe()
# Out:
#                   id  Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# count    1300.000000         1300.000000           1300.000000   1300.000000
# mean   215997.500000            4.253769              4.011538    601.898462
# std       375.421985            1.014814              0.696868    249.856289
# min    215348.000000            0.900000              3.000000    110.000000
# 25%    215672.750000            3.700000              4.000000    405.500000
# 50%    215997.500000            4.200000              4.000000    606.000000
# 75%    216322.250000            4.900000              4.000000    806.000000
# max    216647.000000            6.600000              5.000000   1079.000000
#
#        Акционные_покупки  Средний_просмотр_категорий_за_визит  \
# count        1300.000000                           1300.00000
# mean            0.319808                              3.27000
# std             0.249843                              1.35535
# ...

# %%
mt.describe()
# Out:
#                   id        минут
# count    2600.000000  2600.000000
# mean   215997.500000    13.336154
# std       375.349754     4.080198
# min    215348.000000     4.000000
# 25%    215672.750000    10.000000
# 50%    215997.500000    13.000000
# 75%    216322.250000    16.000000
# max    216647.000000    23.000000

# %%
mm.describe()
# Out:
#                   id        Выручка
# count    3900.000000    3900.000000
# mean   215997.500000    5025.696051
# std       375.325686    1777.704104
# min    215348.000000       0.000000
# 25%    215672.750000    4590.150000
# 50%    215997.500000    4957.500000
# 75%    216322.250000    5363.000000
# max    216647.000000  106862.200000

# %%
mo.describe()
# Out:
#                   id      Прибыль
# count    1300.000000  1300.000000
# mean   215997.500000     3.996631
# std       375.421985     1.013722
# min    215348.000000     0.860000
# 25%    215672.750000     3.300000
# 50%    215997.500000     4.045000
# 75%    216322.250000     4.670000
# max    216647.000000     7.430000

# %%
mf[mf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Покупательская активность, Тип сервиса, Разрешить сообщать, Маркет_актив_6_мес, Маркет_актив_тек_мес, Длительность, Акционные_покупки, Популярная_категория, Средний_просмотр_категорий_за_визит, Неоплаченные_продукты_штук_квартал, Ошибка_сервиса, Страниц_за_визит]
# Index: []

# %%
mt[mt.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Период, минут]
# Index: []

# %%
mm[mm.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Период, Выручка]
# Index: []

# %%
mo[mo.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Прибыль]
# Index: []

# %%
mf.isna().sum()
# Out:
# id                                     0
# Покупательская активность              0
# Тип сервиса                            0
# Разрешить сообщать                     0
# Маркет_актив_6_мес                     0
# Маркет_актив_тек_мес                   0
# Длительность                           0
# Акционные_покупки                      0
# Популярная_категория                   0
# Средний_просмотр_категорий_за_визит    0
# Неоплаченные_продукты_штук_квартал     0
# Ошибка_сервиса                         0
# Страниц_за_визит                       0
# dtype: int64

# %%
mt.isna().sum()
# Out:
# id        0
# Период    0
# минут     0
# dtype: int64

# %%
mm.isna().sum()
# Out:
# id         0
# Период     0
# Выручка    0
# dtype: int64

# %%
mo.isna().sum()
# Out:
# id         0
# Прибыль    0
# dtype: int64

# %% [markdown]
# ### Выводы по шагу 2. Проверил типы данных, проверил пропуски и явные и неявные дубликаты. Все найденные проблемы: опечатки в категориальных столбцах устранены. Убедился, в соответствии числа записей в датафреймах логике. 1300 в основном датафрейме, 2600 (1300 x 2) и 3900 (1300 x 3) соответственно в двух дополнительных датафреймах, в 4-м тоже 1300 записей. Все логично.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️ <br>
# <font color='green'>Здорово, что не забываешь про промежуточные выводы.</font>

# %% [markdown]
# # Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Проведите исследовательский анализ данных из каждой таблицы. Отберите клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Оформите выводы по результатам шага.

# %%
#mf['Покупательская активность'].value_counts()

# %%
mf.groupby(['Покупательская активность']).sum().plot(kind='pie', y='id')
plt.legend(loc='upper right', title='Покупательская активность')

# %%
mf.groupby(['Тип сервиса']).sum().plot(kind='pie', y='id')
plt.legend(loc='upper left', title='Тип сервиса')

# %%
mf.groupby(['Разрешить сообщать']).sum().plot(kind='pie', y='id')
plt.legend(loc='upper left', title='Разрешить сообщать')

# %%
mf.groupby(['Популярная_категория']).sum().plot(kind='pie', y='id')
plt.legend(loc='upper right', title='Популярная категория', handlelength=1, fontsize=3)

# %%
mf['Маркет_актив_6_мес'].hist(bins=16)
plt.title('Среднемесячное значение маркетинговых коммуникаций компании, за 6 месяцев на покупателя')
plt.ylabel('Количество записей')
plt.xlabel('Количество')
plt.show()

# %%
mf['Маркет_актив_тек_мес'].hist(bins=3)
plt.title('Количество маркетинговых коммуникаций в текущем месяце')
plt.ylabel('Количество записей')
plt.xlabel('Количество')
plt.show()

# %%
mf['Длительность'].hist(bins=16)
plt.title('Количество дней, прошедшее с момента регистрации покупателя на сайте')
plt.ylabel('Количество записей')
plt.xlabel('Дней')
plt.show()

# %%
mf['Акционные_покупки'].hist(bins=20)
plt.title('Среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев')
plt.ylabel('Количество записей')
plt.xlabel('Доля')
plt.show()

# %%
mf['Средний_просмотр_категорий_за_визит'].hist(bins=6)
plt.title('Сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца')
plt.ylabel('Количество записей')
plt.xlabel('Количество категорий')
plt.show()

# %%
mf['Неоплаченные_продукты_штук_квартал'].hist(bins=11)
plt.title('Общее число неоплаченных товаров в корзине за последние 3 месяца')
plt.ylabel('Количество записей')
plt.xlabel('Количество')
plt.show()

# %%
mf['Ошибка_сервиса'].hist(bins=10)
plt.title('Число сбоев, которые коснулись покупателя во время посещения сайта')
plt.ylabel('Количество записей')
plt.xlabel('Количество сбоев')
plt.show()

# %%
mf['Страниц_за_визит'].hist(bins=20)
plt.title('Среднее количество страниц, которые посмотрел покупатель за один визит на сайт за 3 месяца')
plt.ylabel('Количество записей')
plt.xlabel('Количество')
plt.show()

# %%
mm.groupby(['Период']).sum().plot(kind='pie', y='id')
plt.legend(loc='upper left', title='Период', fontsize=5)

# %%
mm['Выручка'].hist(bins=16, range=(0,10000))
plt.title('Сумма выручки за период')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.show()

# %%
mm[mm['Период']=='текущий_месяц']['Выручка'].hist(bins=16)
plt.title('Сумма выручки за текущий месяц')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.show()

# %% [markdown]
# Аномалии в зоне больших значений!

# %%
mm[mm['Период']=='текущий_месяц'].sort_values(by='Выручка').head()
# Out:
#           id         Период  Выручка
# 356   215466  текущий_месяц   2758.7
# 2485  216176  текущий_месяц   2952.2
# 390   215478  текущий_месяц   3078.3
# 637   215560  текущий_месяц   3083.7
# 3282  216442  текущий_месяц   3085.4

# %%
mm[mm['Период']=='текущий_месяц'].sort_values(by='Выручка').tail()
# Out:
#           id         Период   Выручка
# 2388  216144  текущий_месяц    7547.8
# 1481  215841  текущий_месяц    7557.0
# 262   215435  текущий_месяц    7605.3
# 435   215493  текущий_месяц    7799.4
# 98    215380  текущий_месяц  106862.2

# %%
mm[mm['Период']=='текущий_месяц']['Выручка'].hist(bins=16, range=(0,8000))
plt.title('Сумма выручки за текущий месяц')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.show()

# %%
mm[mm['Период']=='текущий_месяц']['Выручка'].hist(bins=16, range=(10000, 110000))
plt.title('Сумма выручки за период')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.show()

# %% [markdown]
# Эту аномалию удалю далее.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>Действительно явный выброс.
# Можно удалить, а можно и заполнить, например значением предыдущего месяца.</font>

# %%
mm[mm['Период']=='предыдущий_месяц']['Выручка'].hist(bins=16)
plt.title('Сумма выручки за период')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.show()

# %%
mm[mm['Период']=='предыдущий_месяц']['Выручка'].hist(bins=16, range=(0,2000))
plt.title('Сумма выручки за период')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.show()

# %% [markdown]
# Эти 3 выброса будут обработаны ниже.

# %%
mm[mm['Период']=='препредыдущий_месяц']['Выручка'].hist(bins=16)
plt.title('Сумма выручки за период')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.show()

# %%
mm[mm['Период']=='препредыдущий_месяц']['Выручка'].hist(bins=16, range=(0,2000))
plt.title('Сумма выручки за период')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.show()

# %% [markdown]
# Эти 3 выброса, как будет видно ниже, будут уже обработаны в рамках предыдущей операции.

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Справедливое замечание!</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'> Нужно посмотреть распределения по каждому месяцу отдельно и без ограничения диапазона, для контроля аномалий. </font>

# %%
mm[mm['Выручка']==0]
# Out:
#         id               Период  Выручка
# 0   215348  препредыдущий_месяц      0.0
# 2   215348     предыдущий_месяц      0.0
# 28  215357  препредыдущий_месяц      0.0
# 29  215357     предыдущий_месяц      0.0
# 34  215359     предыдущий_месяц      0.0
# 35  215359  препредыдущий_месяц      0.0

# %% [markdown]
# Для анализа выручки за 3 месяца эти 3 id нам не подходят, удалим этого пользователя.

# %%
list1 = mm[mm['Выручка']==0]['id']
list1 = list1.drop_duplicates().reset_index(drop=True)
list1 = list1.to_list()

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Справедливое замечание!</div>

# %%
mm[mm['Выручка']>10000]['id']
# Out:
# 98    215380
# Name: id, dtype: int64

# %%
mm[mm['id']==215380]
# Out:
#         id               Период   Выручка
# 96  215380  препредыдущий_месяц    5051.0
# 97  215380     предыдущий_месяц    6077.0
# 98  215380        текущий_месяц  106862.2

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Почему выбран именно этот id для анализа?</font>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Справедливое замечание!</div>

# %%
print(mm[mm['Период']=='препредыдущий_месяц']['Выручка'].median())
print(mm[mm['Период']=='предыдущий_месяц']['Выручка'].median())
print(mm[mm['Период']=='текущий_месяц']['Выручка'].median())
# Out:
# 4809.0
# 5005.0
# 5179.950000000001

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Они удалены в следующих 3-х ячейках с кодом.</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'> ~~Нужно удалить пользователей без покупок хотя бы в одном из трёх месяцев, у них активность менее трёх месяцев. Это можно проявить по выручке.~~</font>
# ```text
# Отберите клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период.
# ```

# %% [markdown]
# Мы не знаем, что с выручкой за текущий месяц у id = 215380. Удалим и его.

# %%
list1.append(215380)
mm = mm.query("id not in @list1")
mo = mo.query("id not in @list1")

# %%
mm.describe()
# Out:
#                   id      Выручка
# count    3888.000000  3888.000000
# mean   215999.464506  5007.255658
# std       374.231545   679.193461
# min    215349.000000  2758.700000
# 25%    215675.750000  4591.950000
# 50%    215999.500000  4959.000000
# 75%    216323.250000  5363.000000
# max    216647.000000  7799.400000

# %%
mt.groupby(['Период']).sum().plot(kind='pie', y='id')
plt.legend(loc='upper left', title='Период', fontsize=5)

# %%
mt['минут'].hist(bins=20)
plt.title('Распределение времени, которое покупатель провел на сайте в течение периода')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.show()

# %%
mo['Прибыль'].hist(bins=16)
plt.title('Распределение среднемесячной прибыли за последние 3 месяца')
plt.ylabel('Количество записей')
plt.xlabel('Прибыль магазина от продаж каждому покупателю')
plt.show()

# %% [markdown]
# ### Вывод по шагу 3. Построил круговые диаграммы для категориальных признаков, для того, чтобы понять примерное соотношение признаков, построил гистограммы для количественных признаков, чтобы понять распределения и увидеть вылеты. Здесь были обнаружены проблемы в столбце выручка. 3 пользователя, которые содержали 0-е суммы, это нам мешает в исследовании, они были удалены. И 1 пользователь, у которого была очень большая выручка, правды мы узнать не можем, очевидно, следует этот выброс удалить.

# %% [markdown]
# # Шаг 4. Объединение таблиц

# %% [markdown]
# 4.1 Объедините таблицы market_file.csv, market_money.csv, market_time.csv. Данные о прибыли из файла money.csv при моделировании вам не понадобятся.

# %%
mf = mf.query("id not in @list1")

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>Неактивные удалены 👌</font>

# %%
mt_pred = mt[mt['Период']=='предыдущий_месяц']
new1={'минут':'Минут_предыдущий_месяц'}
mt_pred=mt_pred.rename(columns=new1)

mt_tek = mt[mt['Период']=='текущий_месяц']
new2={'минут':'Минут_текущий_месяц'}
mt_tek=mt_tek.rename(columns=new2)

mm_prepred = mm[mm['Период']=='препредыдущий_месяц']
new3={'Выручка':'Выручка_препредыдущий_месяц'}
mm_prepred=mm_prepred.rename(columns=new3)

mm_pred = mm[mm['Период']=='предыдущий_месяц']
new4={'Выручка':'Выручка_предыдущий_месяц'}
mm_pred=mm_pred.rename(columns=new4)

mm_tek = mm[mm['Период']=='текущий_месяц']
new5={'Выручка':'Выручка_текущий_месяц'}
mm_tek=mm_tek.rename(columns=new5)

del mt_pred['Период']
del mt_tek['Период']
del mm_prepred['Период']
del mm_pred['Период']
del mm_tek['Период']

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Таблицы можно "развернуть вширь" по id  методом pivot_table. Необязательно прописывать каждую колонку.</font>

# %%
df = mf.merge(mt_pred, on='id', how='left')
df = df.merge(mt_tek, on='id', how='left')
df = df.merge(mm_prepred, on='id', how='left')
df = df.merge(mm_pred, on='id', how='left')
df = df.merge(mm_tek, on='id', how='left')

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> Верно, при объединении таблиц нужно привязаться к уникальному `"id"`.</font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1296 entries, 0 to 1295
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1296 non-null   int64
#  1   Покупательская активность            1296 non-null   object
#  2   Тип сервиса                          1296 non-null   object
#  3   Разрешить сообщать                   1296 non-null   object
#  4   Маркет_актив_6_мес                   1296 non-null   float64
#  5   Маркет_актив_тек_мес                 1296 non-null   int64
#  6   Длительность                         1296 non-null   int64
#  7   Акционные_покупки                    1296 non-null   float64
#  8   Популярная_категория                 1296 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1296 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1296 non-null   int64
# ...

# %% [markdown]
# 4.2 Учитывайте, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделайте отдельный столбец для каждого периода.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> 👍</font>

# %% [markdown]
# ### Вывод по шагу 4. С учетом особенностей строения датафреймов из market_money.csv и market_time.csv данные были объединены в один датафрейм.

# %% [markdown]
# # Шаг 5. Корреляционный анализ

# %% [markdown]
#     Проведите корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделайте выводы о мультиколлинеарности и при необходимости устраните её.

# %%
plt.subplots(figsize=(14,6))
sns.heatmap(df[df.columns[1:]].corr(method='spearman'), annot=True, cmap='cividis', fmt='.1g')
# Out:
# <AxesSubplot:>

# %%
df[df.columns[1:]].phik_matrix()
# Out:
# interval columns not set, guessing: ['Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 'Длительность', 'Акционные_покупки', 'Средний_просмотр_категорий_за_визит', 'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса', 'Страниц_за_визит', 'Минут_предыдущий_месяц', 'Минут_текущий_месяц', 'Выручка_препредыдущий_месяц', 'Выручка_предыдущий_месяц', 'Выручка_текущий_месяц']
#                                      Покупательская активность  Тип сервиса  \
# Покупательская активность                             1.000000     0.129940
# Тип сервиса                                           0.129940     1.000000
# Разрешить сообщать                                    0.000000     0.289965
# Маркет_актив_6_мес                                    0.544831     0.089911
# Маркет_актив_тек_мес                                  0.000000     0.045258
# Длительность                                          0.099901     0.401411
# Акционные_покупки                                     0.506276     0.030010
# ...

# %%
interval_cols=['Маркет_актив_6_мес','Маркет_актив_тек_мес', 'Длительность', \
               'Акционные_покупки', 'Средний_просмотр_категорий_за_визит', 'Неоплаченные_продукты_штук_квартал', \
               'Ошибка_сервиса', 'Страниц_за_визит', \
               'Минут_предыдущий_месяц', 'Минут_текущий_месяц', 'Выручка_препредыдущий_месяц', \
               'Выручка_предыдущий_месяц', 'Выручка_текущий_месяц'
]

phik_overview = phik_matrix(df[df.columns[1:]], interval_cols=interval_cols)

plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Спасибо, принято!</div>

# %% [markdown]
# Пойдем по ветке Фи-к. Тогда здесь нет коэффициентов зависимостей более 0.84. Можно попробовать не удалять никакие признаки, т.к. отсутствует мультиколлинеарность.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>Здорово,что применена `phik` для анализа и нелинейных зависимостей</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'>~~Все признаки распределены не нормально, поэтому здесь нужно использовать корреляцию Спирмана или Phik или иные подходы, которые устойчивы к выбросам и ненормальному распределению. Корреляция Пирсона, которая здесь используется по умолчанию, нам не подходит.~~</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'>Можно использовать коэффициент корреляции $\phi_K$ , это передовой способ вычисления коэффициентов корреляции для любых типов признаков. Кроме того, в библиотеке есть визуализация. Стоит учитывать, что этот коэффициент показывает не только линейные связи, но и нелинейные. Более подробно понять вид связи поможет визуализация с помощью диаграмм рассеяния. Ссылка на документацию: https://phik.readthedocs.io/en/latest/
# Пример кода:</font>
# ```python
# from phik.report import plot_correlation_matrix
# from phik import report
#
# # список интервальных признаков
# interval_cols = [...]
#
# # вычисление коэффициентов корреляции phi для датафрейма df
# phik_overview = df.phik_matrix(interval_cols=interval_cols)
#
# # визуализация тепловой карты коэффициентов корреляции
# plot_correlation_matrix(
#     phik_overview.values,
#     x_labels=phik_overview.columns,
#     y_labels=phik_overview.index,
#     title=r"correlation $\phi_K$",
#     fontsize_factor=1.5,
#     figsize=(15, 12)
# )
# ```

# %% [markdown]
# Мультиколлинеарностью называем зависимость с коэффициентом 0.9-0.95.
# У нас таких нет

# %%
df.plot(x='Выручка_предыдущий_месяц', y='Выручка_текущий_месяц',kind='scatter')
plt.title('Зависимость выручки в текущем месяце от выручки в предыдущем месяце\n')
plt.ylabel('Выручка_текущий_месяц')
plt.xlabel('Выручка_предыдущий_месяц')
plt.show()

# %% [markdown]
# Если вдруг мне придется что-тот удалять, то это будет один из этих двух ^ столбцов!

# %% [markdown]
# ### Вывод по шагу 5. Построил матрицу корреляций признаков, мультиколлинеарность не обнаружена.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> 👍</font>

# %% [markdown]
# # Шаг 6. Использование пайплайнов

# %% [markdown]
# Примените все изученные модели. Для этого используйте пайплайны.
#
# 6.1 Во время подготовки данных используйте ColumnTransformer. Количественные и категориальные признаки обработайте в пайплайне раздельно. Для кодирования категориальных признаков используйте как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.
# Напоминаем, что для каждой модели можно подготовить данные с разным кодированием и масштабированием.

# %% [markdown]
# 6.2 Обучите четыре модели: KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и  SVC(). Для каждой из них подберите как минимум один гиперпараметр. Выберите подходящую для задачи метрику, аргументируйте свой выбор. Используйте эту метрику при подборе гиперпараметров.

# %% [markdown]
# 6.3 Выберите лучшую модель, используя заданную метрику. Для этого примените одну из стратегий:
#
#     использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель самостоятельно;
#     использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернёт вам лучшую модель.

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

# загружаем данные
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(['id','Покупательская активность'], axis=1),
    df['Покупательская активность'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = df['Покупательская активность']
)

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test) 

# создаём списки с названиями признаков
ohe_columns = ['Разрешить сообщать', 'Популярная_категория']

ord_columns = ['Тип сервиса']

num_columns = ['Маркет_актив_6_мес','Маркет_актив_тек_мес', 'Длительность', \
               'Акционные_покупки', 'Средний_просмотр_категорий_за_визит', 'Неоплаченные_продукты_штук_квартал', \
               'Ошибка_сервиса', 'Страниц_за_визит', \
               'Минут_предыдущий_месяц', 'Минут_текущий_месяц', 'Выручка_препредыдущий_месяц', \
               'Выручка_предыдущий_месяц', 'Выручка_текущий_месяц']

# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore'))
    ]
    )

# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['стандарт', 'премиум']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 6),
        'models__min_samples_split': range(2, 6),
        'models__min_samples_leaf': range(1, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1,6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели SVC()
    {
        'models': [SVC(probability=True, random_state=RANDOM_STATE)],
        'models__C': range(1,3),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)

# проверьте работу модели на тестовой выборке
# рассчитайте прогноз на тестовых данных

y_test_pred = randomized_search.predict_proba(X_test)
probabilities_one = y_test_pred[:, 1]
print('Площадь ROC-кривой:', roc_auc_score(y_test, probabilities_one))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['Разрешить сообщать',
#                                                    'Популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
# ...

# %%
X_1 = X_train
X_2 = X_test
y_1 = y_train
y_2 = y_test

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Закомментированный код лучше удалять из проекта. Он создаёт впечатление неоконченой работы.</font>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Принято, спасибо!</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ❌\
# <font color='red'> ~~По заданию нужно два Энкодера.\
# Можно передавать в параметрах для LR, KNN и SVC - OHE, а для Дерева перебрать OHE и OE,\
# a можно засунуть в ord_columns какой-нибудь бинарный признак, например 'тип_сервиса'.~~ </font>
# ```text
# Для кодирования категориальных признаков используйте как минимум два кодировщика.
# Напоминаем, что для каждой модели можно подготовить данные с разным кодированием и масштабированием.
# ```

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Спасибо, принято! Исправил.</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> 👍</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'> ~~В SVC нужно передать аргумент probability= True. Что бы можно было работать с вероятностями, если модель выиграет.~~</font>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Спасибо, принято!  Исправил.</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> 👍</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'>~~roc_auc нужно считать по вероятностям классов~~</font>
# ```python
# probabilities = model.predict_proba(features)
# probabilities_one = probabilities[:, 1]
# print('Площадь ROC-кривой:', roc_auc_score(target, probabilities_one))
# ```
# <font color='blue'>Самое подробное объяснение метрики, что я видел на русском языке, можно посмотреть здесь: https://alexanderdyakonov.wordpress.com/2017/07/28/auc-roc-площадь-под-кривой-ошибок \
# А внутри кросс-валидации мы просто указываем метрику ROC_AUC и там никаких вероятностей нам не нужно. Так как эта метрика не дифференцируема на всем промежутке (кажется, разрыв в нуле), то там разработчики кросс-валидации хитро меняют ее на эквивалент Gini, так как Gini = 2 ×AUC_ROC – 1 (можно почитать по ссылке выше)
# </font>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Спасибо, принято! Исправил.</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> 👍</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ❌\
# <font color='red'> Здесь не соответствие версии sklearn. В окружении Практикума стоит 0.24.1, в этой версии сочетание параметров `drop="first" и handle_unknown="ignore"` невозможно. Посмотреть версию библиотеки можно так:
# ```python
# import sklearn
# sklearn.__version__
# ```
# Обновить до последней версии:</font>
# ```
# !pip install -Uq scikit-learn
# ```

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Обновил sklearn до версии 1.5.0.</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ❌\
# <font color='blue'> Установку новой версии библиотеки нужно добавить в тетрадку проекта.</font>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара 2:</b> Добавил в начале!</div>

# %% [markdown]
# ### Вывод по шагу 6.
#
# Выбрана метрика ROC-AUC - площадь под ROC-кривой (график, который отображает динамику качества классификации при разных порогах - график True_positive_rate от False_positive_rate). Т.о. выбранная метрика оценивает качество решений модели в наиболее общем виде, учитывая все возможные пороговые значения. Поэтому она не зависит от того, какой порог выбирается, т.е. это самая общая оценка итого работы модели. Почему она, здесь, в задаче, а не presicion или recall - наша задача выглядит симметрично, поэтому выбор пал на roc_auc, также возможно использование accuracy, но она более частная. Зависит от порогового значения.
#
# Лучшая модель и ее параметры:
#
# LogisticRegression(C=2, penalty='l1', random_state=42, solver='liblinear') с MinMaxScaler().
#
# Метрика лучшей модели на тренировочной выборке: 0.897.
#
# Метрика ROC-AUC на тестовой выборке: 0.918.

# %% [markdown]
# # Шаг 7. Анализ важности признаков

# %% [markdown]
# 7.1 Оцените важность признаков для лучшей модели и постройте график важности с помощью метода SHAP.

# %% [markdown]
# 7.2 Сделайте выводы о значимости признаков:
#
#     какие признаки мало значимы для модели;
#     какие признаки сильнее всего влияют на целевой признак;
#     как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.

# %%
shap.initjs()
best_model = randomized_search.best_estimator_
X_train_shap = pd.DataFrame(
    pipe_final.named_steps['preprocessor'].fit_transform(X_train), 
    columns= pipe_final.named_steps['preprocessor'].get_feature_names_out()
)
X_test_shap = pd.DataFrame(
    pipe_final.named_steps['preprocessor'].fit_transform(X_test), 
    columns= pipe_final.named_steps['preprocessor'].get_feature_names_out()
)
model = LogisticRegression(C=2, penalty='l1', random_state=RANDOM_STATE, solver='liblinear')
model.fit(X_train_shap, y_train)
explainer = shap.Explainer(model.predict_proba, X_train_shap)
shap_values = explainer(X_test_shap)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.plots.beeswarm(shap_values[:,:,1])

# %% [markdown]
# ### Вывод по шагу 7.
#
# Малозначимые для модели признаки, это те, что были здесь объединены в "сумму 11": тип сервиса, разрешение сообщать, активность маркетинговых коммуникаций в текущем месяце, длительность пребывания на сайте, популярные категории - слабо влияют, кроме категории "Мелкая бытовая техника и электроника" - чем больше таких товаров покупает пользователь, тем больше снижается потом его покупательская активность, ошибки сервиса, выручка, кроме выручки за препредыдущий месяц - она оказалась самой важной, время, проведенное за предыдущий и препредыдущий периоды.
#
# Наиболее сильно влияют те, у кого самые высокие по модулю значения по шкале SHAP value: сколько страниц за визит просмотрел покупатель за один визит на сайт за последние 3 месяца, сколько категорий покупатель просмотрел за визит в течение последнего месяца, количество минут проведенных на сайте в предыдущем месяце, доля покупок по акции, число неоплаченных продуктов в корзине и среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев.
#
# Как можно использовать эти наблюдения при моделировании и принятии бизнес-решений? Что напрашивается больше всего: использовать самые влияющие факторы для прогнозирования будущего поведения пользователя и если он собирается соскочить, то вовлечь его обратно. Или не создавая карго-культа довести у каждого пользователя самые важные признаки до нужных уровней (по прогнозу, что они потом останутся) - вероятно при таком подходе большая часть из них станет покупать более активно.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> 👍</font>

# %% [markdown]
# # Шаг 8. Сегментация покупателей

# %% [markdown]
# 8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.

# %% [markdown]
# 8.2 Выберите группу покупателей и предложите, как увеличить её покупательскую активность:
#
#     Проведите графическое и аналитическое исследование группы покупателей.
#     Сделайте предложения по работе с сегментом для увеличения покупательской активности.

# %% [markdown]
# 8.3 Сделайте выводы о сегментах:
#
#     какой сегмент вы взяли для дополнительного исследования,
#     какие предложения вы сделали и почему.

# %% [markdown]
# В качестве исследуемого сегмента будет выбран сегмент группы клиентов с высокой вероятностью снижения покупательской активности и ниболее высокой прибыльности!

# %%
df2 = df.merge(mo, on='id', how='left')

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> 👍</font>

# %%
X_1_0, X_2_0, y_1_0, y_2_0 = train_test_split(
    df2.drop(['Покупательская активность'], axis=1),
    df2['Покупательская активность'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = df['Покупательская активность']
)

# %%
X_3_0 = pd.concat([X_1_0,X_2_0])

# %%
X_3 = X_3_0.drop(['id','Прибыль'], axis=1)

# %%
best_model = randomized_search.best_estimator_

X_4 = pd.DataFrame(
    pipe_final.named_steps['preprocessor'].fit_transform(X_3), 
    columns= pipe_final.named_steps['preprocessor'].get_feature_names_out()
)
    
y_4 = model.predict_proba(X_4)
probabilities_one_0 = y_4[:, 1]

# %%
probas_1 = pd.Series(probabilities_one_0)

# %%
X_3.insert(loc=16,column='Прогноз_снижения', value=probabilities_one_0)

# %%
X_3.insert(loc=17,column='Прибыль', value=X_3_0['Прибыль'])

# %% [markdown]
# 1 - снизилась покупательская активность, 0 - прежний уровень.

# %%
X_3.plot(x='Прибыль', y='Прогноз_снижения',kind='scatter')
plt.title('График вероятности снижения покупательской активности от прибыли\n\n')
plt.ylabel('Вероятность снижения покупательской активности')
plt.xlabel('Прибыль')
plt.show()

# %% [markdown]
# Нас интересует максимальная прибыль и мы тут видим 2 облака. Есть смысл лезть в область, где мы уверены, что у пользователя снизится потребительская активность. Возьмем отсечку по вероятности = 0.75, будем разбираться только с такими. А по прибыли облако на графике находится в диапазоне от 2.5 до 5.5. Такое и рассмотрим.

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара 2:</b> Теперь график рассеяния сделал по всей выборке!</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 3: </b></font> ✔️\
# <font color='green'> 👍</font>

# %%
df4 = X_3[(X_3['Прибыль']>2.5)&(X_3['Прибыль']<5.5)&(X_3['Прогноз_снижения']>0.75)]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 303 entries, 363 to 318
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Тип сервиса                          303 non-null    object
#  1   Разрешить сообщать                   303 non-null    object
#  2   Маркет_актив_6_мес                   303 non-null    float64
#  3   Маркет_актив_тек_мес                 303 non-null    int64
#  4   Длительность                         303 non-null    int64
#  5   Акционные_покупки                    303 non-null    float64
#  6   Популярная_категория                 303 non-null    object
#  7   Средний_просмотр_категорий_за_визит  303 non-null    int64
#  8   Неоплаченные_продукты_штук_квартал   303 non-null    int64
#  9   Ошибка_сервиса                       303 non-null    int64
#  10  Страниц_за_визит                     303 non-null    int64
# ...

# %%
mf['Акционные_покупки'].hist(bins=20)
plt.title('Среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев')
plt.ylabel('Количество записей')
plt.xlabel('Доля')
plt.show()

# %% [markdown]
# Рассмотрим сегмент покупателей, которые берут преимущественно акционные товары. По графику можно предположить, что это те, у кого доля покупок по акции > 80%.

# %%
df4_disc = df4[df4['Акционные_покупки']>0.8]

# %%
df4_nodisc = df4[df4['Акционные_покупки']<=0.8]

# %%
df4_nodisc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 363 to 364
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Тип сервиса                          193 non-null    object
#  1   Разрешить сообщать                   193 non-null    object
#  2   Маркет_актив_6_мес                   193 non-null    float64
#  3   Маркет_актив_тек_мес                 193 non-null    int64
#  4   Длительность                         193 non-null    int64
#  5   Акционные_покупки                    193 non-null    float64
#  6   Популярная_категория                 193 non-null    object
#  7   Средний_просмотр_категорий_за_визит  193 non-null    int64
#  8   Неоплаченные_продукты_штук_квартал   193 non-null    int64
#  9   Ошибка_сервиса                       193 non-null    int64
#  10  Страниц_за_визит                     193 non-null    int64
# ...

# %%
df4_disc['Прибыль'].median()
# Out:
# 4.05

# %%
df4_nodisc['Прибыль'].median()
# Out:
# 4.12

# %% [markdown]
# Рассмотрим наш сегмент в интересующей нас группе по самым важным критериям (SHAP).

# %% [markdown]
# По Шепли-графику видно, что чем больше доля покупок по акции, тем выше вероятность снижения покупательской активности - покупатель забегал исключительно на выгодные акции и он здесь только ради них. Видно, что в среднем, в облаке, покупатели без дисконта приносят бОльший доход, чем акционные покупатели.

# %%
a1 = 10
plt.hist(df4_disc['Страниц_за_визит'], bins = a1, alpha=0.5, label='Акционные покупатели')
plt.hist(df4_nodisc['Страниц_за_визит'], bins = a1, alpha=0.5, label='Обычные покупатели')
plt.title('Страниц за визит')
plt.ylabel('Количество записей')
plt.xlabel('Страниц за визит')
plt.legend()
plt.show()

# %% [markdown]
# Акционных покупателей меньше, поэтому сраниваем форму и распределения. Они довольно близки, тут сегменты не различаются. Чем меньше страниц посещает пользователь, тем больше вероятность, что снизится его покупательская активность.

# %%
a1 = 6
plt.hist(df4_disc['Средний_просмотр_категорий_за_визит'], bins = a1, alpha=0.5, label='Акционные покупатели')
plt.hist(df4_nodisc['Средний_просмотр_категорий_за_визит'], bins = a1, alpha=0.5, label='Обычные покупатели')
plt.title('Кол-во категорий, которое смотрел пользователь за визит')
plt.ylabel('Количество записей')
plt.xlabel('Категорий за визит')
plt.legend()
plt.show()

# %% [markdown]
# Здесь сегменты не различаются. Чем меньше категорий за визит смотрит пользователь, тем больше вероятность, что снизится его покупательская активность.

# %%
a1 = 6
plt.hist(df4_disc['Минут_предыдущий_месяц'], bins = a1, alpha=0.5, label='Акционные покупатели')
plt.hist(df4_nodisc['Минут_предыдущий_месяц'], bins = a1, alpha=0.5, label='Обычные покупатели')
plt.title('Время, проведенное на сайте в предыдущий месяц')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.legend()
plt.show()

# %% [markdown]
# Здесь сегменты вновь не различаются. Чем меньше категорий за визит смотрит пользователь, тем больше вероятность, что снизится его покупательская активность.

# %%
df4_disc.groupby(['Популярная_категория']).count().plot(kind='pie', y='Страниц_за_визит')
plt.legend(loc='upper right', title='Популярная категория', handlelength=1, fontsize=3)

# %%
df4_nodisc.groupby(['Популярная_категория']).count().plot(kind='pie', y='Страниц_за_визит')
plt.legend(loc='upper right', title='Популярная категория', handlelength=1, fontsize=3)

# %% [markdown]
# Доля категории "мелкая бытовая техника и электроника (МБТиЭ)" равна у этих двух исследуемых сегментов. У кого любимая категория "МБТиЭ" - склонны терять покупательскую активность.

# %%
a1 = 6
plt.hist(df4_disc['Минут_текущий_месяц'], bins = a1, alpha=0.5, label='Акционные покупатели')
plt.hist(df4_nodisc['Минут_текущий_месяц'], bins = a1, alpha=0.5, label='Обычные покупатели')
plt.title('Время, проведенное на сайте в текущий месяц')
plt.ylabel('Количество записей')
plt.xlabel('Минут')
plt.legend()
plt.show()

# %% [markdown]
# Тут немного интереснее! Видим, что обычные пользователи в текущем месяце провели на сайте меньше времени, чем "акционеры". Вероятно, это связано с тем, что акционеры ищут наиболее выгодные покупки, сравнивают цены с другими магазинами.
#
# Ну а что касается активности, то чем больше проведет пользователь времени на сайте, тем выгоднее для бизнеса - выше вероятность сохранения покупательской активности. Тут хочется порекомендовать вовлекать оставаться на сайте и проходить по различных кнопкам на сайте "обычных" пользователей. Это даст неплохой буст.

# %%
a1 = 11
plt.hist(df4_disc['Неоплаченные_продукты_штук_квартал'], bins = a1, alpha=0.5, label='Акционные покупатели')
plt.hist(df4_nodisc['Неоплаченные_продукты_штук_квартал'], bins = a1, alpha=0.5, label='Обычные покупатели')
plt.title('Кол-во невыкупленных из корзины товаров')
plt.ylabel('Количество записей')
plt.xlabel('Кол-во товаров, оставшихся в корзине')
plt.legend()
plt.show()

# %% [markdown]
# Здесь сегменты вновь не различаются. Чем больше продуктов из корзины не выкупает пользователь, тем больше верояность, что снизится его покупательская активность.

# %%
a1 = 11
plt.hist(df4_disc['Маркет_актив_6_мес'], bins = a1, alpha=0.5, label='Акционные покупатели')
plt.hist(df4_nodisc['Маркет_актив_6_мес'], bins = a1, alpha=0.5, label='Обычные покупатели')
plt.title('Среднее количество маркетинговых коммуникаций за 6 месяцев')
plt.ylabel('Количество записей')
plt.xlabel('Маркетинговых коммуникаций')
plt.legend()
plt.show()

# %% [markdown]
# Сегменты несколько различаются. Чем больше маркетинговых коммуникаций, тем лучше для покупательской активности. Рекомендуется проводить больше коммуникаций с "обычными" покупателями.

# %%
a1 = 20
plt.hist(df4_disc['Выручка_препредыдущий_месяц'], bins = a1, alpha=0.5, label='Акционные покупатели')
plt.hist(df4_nodisc['Выручка_препредыдущий_месяц'], bins = a1, alpha=0.5, label='Обычные покупатели')
plt.title('Выручка за препредыдущий месяц')
plt.ylabel('Количество записей')
plt.xlabel('Выручка в позапрошлый месяц')
plt.legend()
plt.show()

# %% [markdown]
# Сегменты несколько различаются. Чем больше выручка в препредыдущий месяц, тем лучше для покупательской активности. Покупая человек становится "верным" клиентов магазину, если магазин как-то не разочарует/не расстроит покупателя.
#
# В среднем, мы видим, что в позапрошлом месяце средняя выручка от акционного пользователя была выше, чем от обычного.

# %% [markdown]
# Для сохранения покупательской активности, следует провести проактивные действия. Как вариант, можно создать дополнительную скидку на товары или бонусные баллы для этой категории покупателей. Думаю, улучшение рекомендательных систем или увеличение удобства пользовательского опыта покупателя могут также дать хороший выхлоп в плане продаж. Акционные покупателей можно удержать только другими новыми акционными товарами, а оно магазину нужно вообще? В целом, для увеличения акционных продаж и нет, следует завлекать пользователя проводить больше времени на сайте, посещать больше страниц, смотреть больше категорий, проводить с покупателями больше маркетинговых коммуникаций.
#
# Также можно сделать вывод, что те люди, которые склонны к покупкам по акции, они сидят на сайте дольше и с ними было больше маркетинговых коммуникаций. Т.е. больше внимания им, больше внимания от них - и вуаля, они покупают. И делают это только с акционными товарами. Как бы нам это не стало в убыток, если магазин на акционных товарах совсем ничего не зарабатывает, например.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ❌\
# <font color='red'> Сегмент нужно выбрать из всего датасета. В тестовой выборке слишком мало примеров.</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ❌\
# <font color='red'> Нужно выделить сегмент по двум переменным (вероятность снижения и прибыль), для этого определяем и аргументируем два порога по этим осям, проще всего это посмотреть на рассеивание.
# ![](https://i.postimg.cc/DZ3GSqwK/102458.png)
#
# Это, условно, те с кем имеет смысл работать.\
# Затем определяем группу клиентов из сегмента (например по акционным покупкам) и сравниваем этих клиентов со всеми остальньнымим по другим факторам, для выявления различий (можно строить парные графики или накладывать гистограммы). На основании сравнения формируем рекомендации.</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ❌
#
# ```text
# 8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.
# ```
# <font color='red'> Попробую описать, что мы должны сделать:
#
# Самое важное − мы должны по заданию выбрать некоторый сегмент пользователей, обосновать выбор сегмента, обосновать то, как мы этот сегмент определяем (почему выбираем такие значения признаков для отбора пользователей в сегмент), а дальше исследовать только этот сегмент.
#
# При выделении сегмента нужно опираться на две шкалы:
# - вероятность снижения, предикты лучшей модели полученые методом `predict_proba`() по интересующему нас классу ("Снизилось"), и
# - Прибыль от клиентов из таблицы money.csv
#
# Границы сегмента по этим двум шкалам можно определить самостоятельно, например по диаграмме рассеяния, где по одной оси будет результат моделирования (вероятность снижения), а по другой прибыль.
#
# Далее проводим Анализ данных по выбраному сегменту и какой нибудь группы клиентов, например, которые посещают мало страниц.\
# Формулируем предложение по работе с сегментом для увеличения покупательской активности.</font>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Спасибо, Павел!</div>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 3: </b></font> ✔️\
# <font color='green'> 👍</font>

# %% [markdown]
# # Шаг 9. Общий вывод

# %% [markdown]
# Сделайте общий вывод:
#
#     опишите задачу;
#     опишите исходные данные и проведённую предобработку;
#     напишите, что вы сделали для поиска лучшей модели;
#     укажите лучшую модель;
#     добавьте выводы и дополнительные предложения для выбранного сегмента покупателей.

# %% [markdown]
# Исследование завершено. Задача была разработать модель для онлайн-магазина, которая могла бы предсказать вероятность снижения покупательской активности. Плюс выделить сегмент покупателей, проанализировать его, предложить как увеличить покупательскую активность.
#
# Исходные данные данные представляли собой данные о 1300 пользователях в 4-х .csv-файлах. Была проведена предобработка данных и исследовательский+корреляционный анализы: проверка на дубликаты, исправления опечаток и несогласованностей в данных. Удалены 4 пользователя. Далее 3 предобработанных дата сета, посвященные пользователям, о их поведении на сайте, о коммуникации с пользователем, о его продуктовом поведении, времени проведенном на сайте и выручке пошли входными данными для моделей машинного обучения: для поиска лучшей модели машинного обучения и наиболее эффективного прогнозирования поведения покупателей был создан пайплайн, в котором с помощью метода RandomizedSearchCV перебирались 4 модели машинного обучения: логистической регрессии, k-ближайших соседей, случайный лес и метод опорных вектором с различными гиперпараметрами и методами кодирования и масштабирования, в качестве метрики была выбрана метрика roc_auc.
#
# Лучшей моделью оказалась модель LogisticRegression(C=2, penalty='l1', random_state=42, solver='liblinear') с MinMaxScaler().
#
# Метрика лучшей модели на тренировочной выборке: 0.897.
#
# Метрика ROC-AUC на тестовой выборке: 0.893.
#
# По результатам работы модели посмотрел сегмент покупателей с высокой долей покупок по акции и высокой вероятности снижения покупательской активности. Они имеют средние значения по "прибыли", тем не менее, медиана этого показателя у них составляет серьезное значение 4.17. Терять деньги - плохо, предложены потенциальные мероприятия по удержанию покупательской активности.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'> Очень приятно видеть вывод в конце проекта!\
# Приведены ответы на главные вопросы проекта.</font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера</b></font>\
# <font color='green'>Айдар, хороший проект получился!
# Большое спасибо за проделанную работу. Видно, что приложено много усилий.
# Выводы и рассуждения получились содержательными, их было интересно читать.
# </font>
#
# <font color='steelblue'>Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)</font>
#
# <font color='blue'><b>Жду твой проект на повторном ревью. До встречи :) </b></font>

# %% [markdown]
# <div class="alert alert-info"> <b>🎓 Комментарий Айдара:</b> Павел, благодарю тебя за ревью!</div>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера 2</b></font>\
# <font color='green'>Айдар, большое спасибо за доработку.
# </font>
#
# <font color='blue'>Что нужно исправить:</font>
# <ul><font color='red'>Добавь в среду выполнения требуемые зависимости.</font></ul>
# <ul><font color='red'>Поправь сегментацию клиентов.</font></ul>
#
# <font color='blue'>Что можно сделать лучше:</font>
# <font color='darkorange'>В работе я оставил несколько советов. Буду рад, если ты учтешь их.</font></ul>
#
# <font color='blue'><b>Жду новую версию проекта :)</b></font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера 3</b></font>\
# <font color='green'> Айдар, проект принят! \
# Все этапы пройдены. Все рекомендации учтены.\
# Надеюсь, тебе понравился процесс выполнения и результат.</font> \
# <font color='blue'><b>Спасибо, удачи в освоении профессии!</b></font>
